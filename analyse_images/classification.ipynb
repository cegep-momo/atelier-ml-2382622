# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
#On crée des catégories à l'aide du module Keras
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
#Répartition des données d'entrainement en données d'apprentissage et données de validation
#80% de donnée d'apprentissage et 20% de donnée de validation
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# On redimensionne les images au format 28*28 et on réalise un scaling sur les données des pixels
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
#Preparation des données de tests
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8125 - loss: 0.5444 - val_accuracy: 0.8538 - val_loss: 0.3982
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8766 - loss: 0.3493 - val_accuracy: 0.8861 - val_loss: 0.3273
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8903 - loss: 0.3107 - val_accuracy: 0.8901 - val_loss: 0.3127
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8997 - loss: 0.2823 - val_accuracy: 0.8979 - val_loss: 0.2882
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9074 - loss: 0.2612 - val_accuracy: 0.8948 - val_loss: 0.2992
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9112 - loss: 0.2479 - val_accuracy: 0.9046 - val_loss: 0.2713
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9152 - loss: 0.2339 - val_accuracy: 0.9076 - val_loss: 0.2631
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9199 - loss: 0.2235 - val_accuracy: 0.9097 - val_loss: 0.2539
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9234 - loss: 0.2123 - val_accuracy: 0.9076 - val_loss: 0.2588
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9290 - loss: 0.1990 - val_accuracy: 0.9106 - val_loss: 0.2494

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Plot training & validation loss values
plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()
# Out:
# Erreur: 0.23576109111309052
# Précision: 0.9143000245094299

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8283 - loss: 0.4620 - val_accuracy: 0.8421 - val_loss: 0.4321
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8672 - loss: 0.4173
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.4173 - val_accuracy: 0.8350 - val_loss: 0.4355
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8469 - loss: 0.4109 - val_accuracy: 0.8584 - val_loss: 0.3853
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8477 - loss: 0.3982 - val_accuracy: 0.8601 - val_loss: 0.3883
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8559 - loss: 0.3870 - val_accuracy: 0.8618 - val_loss: 0.3734
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3673 - val_accuracy: 0.8600 - val_loss: 0.3770
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8604 - loss: 0.3764 - val_accuracy: 0.8607 - val_loss: 0.3729
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - loss: 0.3181 - val_accuracy: 0.8620 - val_loss: 0.3749
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8656 - loss: 0.3623 - val_accuracy: 0.8689 - val_loss: 0.3530
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.3994 - val_accuracy: 0.8654 - val_loss: 0.3547
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8681 - loss: 0.3547 - val_accuracy: 0.8769 - val_loss: 0.3459
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8633 - loss: 0.3816 - val_accuracy: 0.8729 - val_loss: 0.3486
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8730 - loss: 0.3448 - val_accuracy: 0.8730 - val_loss: 0.3458
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3132 - val_accuracy: 0.8765 - val_loss: 0.3355
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8733 - loss: 0.3415 - val_accuracy: 0.8765 - val_loss: 0.3350
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8477 - loss: 0.3677 - val_accuracy: 0.8736 - val_loss: 0.3423
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8770 - loss: 0.3320 - val_accuracy: 0.8736 - val_loss: 0.3355
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3615 - val_accuracy: 0.8763 - val_loss: 0.3313
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8748 - loss: 0.3301 - val_accuracy: 0.8657 - val_loss: 0.3489
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.3146 - val_accuracy: 0.8704 - val_loss: 0.3415
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8802 - loss: 0.3219 - val_accuracy: 0.8766 - val_loss: 0.3280
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8945 - loss: 0.2356 - val_accuracy: 0.8770 - val_loss: 0.3272
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8803 - loss: 0.3192 - val_accuracy: 0.8803 - val_loss: 0.3224
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8906 - loss: 0.3176 - val_accuracy: 0.8790 - val_loss: 0.3214
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8829 - loss: 0.3155 - val_accuracy: 0.8844 - val_loss: 0.3046
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2767 - val_accuracy: 0.8826 - val_loss: 0.3134
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8850 - loss: 0.3095 - val_accuracy: 0.8832 - val_loss: 0.3142
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.3547 - val_accuracy: 0.8859 - val_loss: 0.3053
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8866 - loss: 0.3035 - val_accuracy: 0.8893 - val_loss: 0.3030
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.3154 - val_accuracy: 0.8867 - val_loss: 0.3063
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8875 - loss: 0.3015 - val_accuracy: 0.8865 - val_loss: 0.3058
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8477 - loss: 0.3608 - val_accuracy: 0.8849 - val_loss: 0.3091
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8881 - loss: 0.3013 - val_accuracy: 0.8866 - val_loss: 0.3052
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9219 - loss: 0.2137 - val_accuracy: 0.8844 - val_loss: 0.3120
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.8890 - loss: 0.2973 - val_accuracy: 0.8849 - val_loss: 0.3028
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8945 - loss: 0.2790 - val_accuracy: 0.8885 - val_loss: 0.3026
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8915 - loss: 0.2939 - val_accuracy: 0.8854 - val_loss: 0.3044
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8945 - loss: 0.2812 - val_accuracy: 0.8837 - val_loss: 0.3096
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.8923 - loss: 0.2905 - val_accuracy: 0.8817 - val_loss: 0.3177
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9180 - loss: 0.2311 - val_accuracy: 0.8865 - val_loss: 0.3083
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.8929 - loss: 0.2866 - val_accuracy: 0.8772 - val_loss: 0.3213
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8867 - loss: 0.2808 - val_accuracy: 0.8854 - val_loss: 0.3062
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8930 - loss: 0.2885 - val_accuracy: 0.8881 - val_loss: 0.2947
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8633 - loss: 0.3904 - val_accuracy: 0.8889 - val_loss: 0.2985
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8957 - loss: 0.2829 - val_accuracy: 0.8903 - val_loss: 0.2939
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9023 - loss: 0.2889 - val_accuracy: 0.8905 - val_loss: 0.2967
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.8948 - loss: 0.2832 - val_accuracy: 0.8998 - val_loss: 0.2817
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8711 - loss: 0.3265 - val_accuracy: 0.8940 - val_loss: 0.2861
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 0.8951 - loss: 0.2817 - val_accuracy: 0.8899 - val_loss: 0.2909
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9102 - loss: 0.2362 - val_accuracy: 0.8927 - val_loss: 0.2917
# Erreur : 0.23666630685329437
# Précision: 0.9160000085830688

# %%
#Sauvegarde du modèle
# Serialisation du modèle 
model_json = reseauNeurone1Convolution.to_json() 
with open("../modele/modele.json", "w") as json_file:
    json_file.write(model_json)
    
# Serialisation des poids
reseauNeurone1Convolution.save_weights("../modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !

# %%
from keras.layers import BatchNormalization

reseauNeurones4Convolution = Sequential()

reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=dimentionImage))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(MaxPooling2D(pool_size=(2, 2)))
reseauNeurones4Convolution.add(Dropout(0.25))

reseauNeurones4Convolution.add(Flatten())
reseauNeurones4Convolution.add(Dense(512, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(128, activation='relu'))
reseauNeurones4Convolution.add(BatchNormalization())
reseauNeurones4Convolution.add(Dropout(0.5))

reseauNeurones4Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurones4Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

historique_apprentissage = reseauNeurones4Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - accuracy: 0.7407 - loss: 0.7420 - val_accuracy: 0.1136 - val_loss: 3.7684
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.8425 - loss: 0.4385 - val_accuracy: 0.4735 - val_loss: 1.9210
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.8697 - loss: 0.3646 - val_accuracy: 0.8097 - val_loss: 0.5261
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.8849 - loss: 0.3234 - val_accuracy: 0.8493 - val_loss: 0.4539
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.8936 - loss: 0.2990 - val_accuracy: 0.9057 - val_loss: 0.2604
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8997 - loss: 0.2811 - val_accuracy: 0.9040 - val_loss: 0.2679
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 87ms/step - accuracy: 0.9050 - loss: 0.2651 - val_accuracy: 0.9034 - val_loss: 0.2702
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.9093 - loss: 0.2516 - val_accuracy: 0.9172 - val_loss: 0.2299
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 16s 86ms/step - accuracy: 0.9133 - loss: 0.2415 - val_accuracy: 0.9171 - val_loss: 0.2265
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.9198 - loss: 0.2288 - val_accuracy: 0.9128 - val_loss: 0.2394

# %%
evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.22901426255702972
# Précision: 0.9196000099182129

# %%
historique_apprentissage = reseauNeurones4Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurones4Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 83ms/step - accuracy: 0.8535 - loss: 0.4025 - val_accuracy: 0.8802 - val_loss: 0.3285
# Epoch 2/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8828 - loss: 0.3256 - val_accuracy: 0.8758 - val_loss: 0.3387
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 16s 88ms/step - accuracy: 0.8713 - loss: 0.3561 - val_accuracy: 0.8906 - val_loss: 0.3018
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8477 - loss: 0.4000 - val_accuracy: 0.8875 - val_loss: 0.2997
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8787 - loss: 0.3379 - val_accuracy: 0.8833 - val_loss: 0.3119
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.3903 - val_accuracy: 0.8817 - val_loss: 0.3156
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 98ms/step - accuracy: 0.8817 - loss: 0.3312 - val_accuracy: 0.8949 - val_loss: 0.2927
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8867 - loss: 0.2792 - val_accuracy: 0.8947 - val_loss: 0.2920
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.8865 - loss: 0.3168 - val_accuracy: 0.8769 - val_loss: 0.3575
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.3309 - val_accuracy: 0.8752 - val_loss: 0.3528
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.8868 - loss: 0.3145 - val_accuracy: 0.8881 - val_loss: 0.2947
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.3377 - val_accuracy: 0.8972 - val_loss: 0.2749
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.8880 - loss: 0.3092 - val_accuracy: 0.8984 - val_loss: 0.2785
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8750 - loss: 0.3403 - val_accuracy: 0.8981 - val_loss: 0.2775
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.8908 - loss: 0.3003 - val_accuracy: 0.8942 - val_loss: 0.2892
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8984 - loss: 0.3036 - val_accuracy: 0.8936 - val_loss: 0.2936
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.8928 - loss: 0.2982 - val_accuracy: 0.8998 - val_loss: 0.2693
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9258 - loss: 0.2406 - val_accuracy: 0.9014 - val_loss: 0.2709
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8953 - loss: 0.2882 - val_accuracy: 0.8969 - val_loss: 0.2725
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8477 - loss: 0.3414 - val_accuracy: 0.9010 - val_loss: 0.2640
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8971 - loss: 0.2855 - val_accuracy: 0.9079 - val_loss: 0.2566
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8672 - loss: 0.3534 - val_accuracy: 0.9065 - val_loss: 0.2631
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8965 - loss: 0.2853 - val_accuracy: 0.9083 - val_loss: 0.2478
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8594 - loss: 0.3954 - val_accuracy: 0.9072 - val_loss: 0.2479
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 92ms/step - accuracy: 0.8990 - loss: 0.2800 - val_accuracy: 0.9052 - val_loss: 0.2612
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.2975 - val_accuracy: 0.9059 - val_loss: 0.2614
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.8996 - loss: 0.2758 - val_accuracy: 0.9079 - val_loss: 0.2583
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8828 - loss: 0.3279 - val_accuracy: 0.9090 - val_loss: 0.2554
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.8990 - loss: 0.2766 - val_accuracy: 0.9112 - val_loss: 0.2408
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8984 - loss: 0.2788 - val_accuracy: 0.9068 - val_loss: 0.2548
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 19s 100ms/step - accuracy: 0.9021 - loss: 0.2699 - val_accuracy: 0.9038 - val_loss: 0.2595
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9180 - loss: 0.2128 - val_accuracy: 0.9054 - val_loss: 0.2498
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9022 - loss: 0.2694 - val_accuracy: 0.9023 - val_loss: 0.2674
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9258 - loss: 0.2023 - val_accuracy: 0.8978 - val_loss: 0.2760
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 94ms/step - accuracy: 0.9052 - loss: 0.2616 - val_accuracy: 0.9119 - val_loss: 0.2408
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8984 - loss: 0.2418 - val_accuracy: 0.9130 - val_loss: 0.2400
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 93ms/step - accuracy: 0.9051 - loss: 0.2619 - val_accuracy: 0.9159 - val_loss: 0.2373
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9219 - loss: 0.2320 - val_accuracy: 0.9153 - val_loss: 0.2369
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 97ms/step - accuracy: 0.9048 - loss: 0.2630 - val_accuracy: 0.9108 - val_loss: 0.2430
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9141 - loss: 0.2172 - val_accuracy: 0.9088 - val_loss: 0.2472
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.9071 - loss: 0.2561 - val_accuracy: 0.9124 - val_loss: 0.2393
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8906 - loss: 0.3363 - val_accuracy: 0.9145 - val_loss: 0.2345
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.9077 - loss: 0.2569 - val_accuracy: 0.9158 - val_loss: 0.2344
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9258 - loss: 0.2414 - val_accuracy: 0.9175 - val_loss: 0.2337
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.9066 - loss: 0.2574 - val_accuracy: 0.9129 - val_loss: 0.2350
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8711 - loss: 0.3435 - val_accuracy: 0.9142 - val_loss: 0.2351
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 96ms/step - accuracy: 0.9100 - loss: 0.2503 - val_accuracy: 0.9175 - val_loss: 0.2258
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8984 - loss: 0.3373 - val_accuracy: 0.9176 - val_loss: 0.2288
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 18s 95ms/step - accuracy: 0.9104 - loss: 0.2466 - val_accuracy: 0.9114 - val_loss: 0.2459
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9180 - loss: 0.2309 - val_accuracy: 0.9108 - val_loss: 0.2445
# Erreur : 0.21073086559772491
# Précision: 0.9229999780654907
